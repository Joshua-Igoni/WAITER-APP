# %%
welcome_note = 'welcome to krusty crab'
taking_order = 'may i take your order Sir/Maam?'
print(welcome_note)
print(taking_order)
show_menu = ['1. krabbypaddy $5', '2. water $1', '3. hott coffee $7', '4. marcoroni and cheese $10']
input_1 =input()
if (input_1 == "yes"):
    for i in show_menu:
        print(i)
    input_2 = int(input('your order Sir/Maam?'))
    if input_2 == 1:
        input_4 = int(input('how many krabbypaddy(s) do you want?'))
        order = (f"""{input_4} krabbypaddy(s) coming up""")
        Total_bill = (f"Total bill: ${input_4*5}")
        for i in show_menu:
            print(i)
        print('5. nothing else')
        input_3 = int(input('anything else?'))
        if input_3 == 1:
            print('you have already ordered for krabbypaddy, please take a new order')
            print(order)
            print(Total_bill)
        elif input_3 == 2:
            input_5 = int(input('how many bottle(s) of water?'))
            input_3 = int(input('anything else?'))
            if input_3 == 1:
                input_23 = int(input('how many more krabbypaddy(s) do you want?'))
                input_3 = int(input('anything else?'))
                if input_3 == 1:
                    input_28 = int(input('how many more krabbypaddy(s) do you want?'))
                    order = (f"""{input_4+input_23+input_28} krabbypaddy(s) and {input_5} bottle(s) of water coming up""")
                    Total_bill = (f"Total bill: ${((input_4+input_23+input_28)*5)+(input_5*1)}")
                elif input_3 == 2:
                    input_29 = int(input('how many more bottle(s) of water do you want?'))
                    order = (f"""{input_4+input_23} krabbypaddy(s) and {input_5+input_29} bottle(s) of water coming up""")
                    Total_bill = (f"Total bill: ${((input_4+input_23)*5)+((input_5+input_29)*1)}")
                elif input_3 == 3:
                    input_6 = int(input('how many cup(s) of hot coffee do you want?'))
                    order = (f"""{input_4+input_23} krabbypaddy(s), {input_5} bottle(s) of water and {input_6} cup(s) of hot coffee coming up""")
                    Total_bill = (f"Total bill: ${((input_4+input_23)*5)+(input_5*1)+(input_6*7)}")
                elif
                print(order)
                print(Total_bill)
                order = (f"""{input_4+input_23} krabbypaddy(s) and {input_5} bottle(s) of water coming up""")
                Total_bill = (f"Total bill: ${((input_4+input_23)*5)+(input_5*1)}")
            elif input_3 == 2:
                input_24 = int(input('how many more bottle(s) of water do you want?'))
                order = (f"""{input_4} krabbypaddy(s) and {input_5+input_24} bottle(s) of water coming up""")
                Total_bill = (f"Total bill: ${(input_4*5)+((input_5+input_24)*1)}")
            elif input_3 == 3:
                input_6 = int(input('how many cup(s) of hot coffee do you want?'))
                order = (f"""{input_4} krabbypaddy(s), {input_5} bottle(s) of water and {input_6} cup(s) of hot coffee coming up""")
                Total_bill = (f"Total bill: ${(input_4*5)+(input_5*1)+(input_6*7)}")
            elif input_3 == 4:
                input_7 = int(input('how many marcoroni and cheese do you want?'))
                order = (f"""{input_4} krabbypaddy(s), {input_5} bottle(s) of water and {input_7} marcoroni and cheese coming up""")
                Total_bill = (f"Total bill: ${(input_4*5)+(input_5*1)+(input_7*10)}")
            elif input_3 == 5:
                order = (f"""{input_4} krabbypaddy(s) and {input_5} bottle(s) of water coming up""")
                Total_bill = (f"Total bill: ${(input_4*5)+(input_5*1)}")
            else:
                print('invalid input, please pick a number from the list.')
            print(order)
            print(Total_bill)
        elif input_3 == 3:
            input_6 = int(input('how many cup(s) of hot coffee?'))
            input_3 = int(input('anything else?'))
            if input_3 == 1:
                input_25 = int(input('how many more krabbypaddy(s) do you want?'))
                order = (f"""{input_4+input_25} krabbypaddy(s) and {input_6} cup(s) of hot coffee coming up""")
                Total_bill = (f"Total bill: ${((input_4+input_25)*5)+(input_6*7)}")
            elif input_3 == 2:
                input_5 = int(input('how many bottle(s) of water do you want?'))
                order = (f"""{input_4} krabbypaddy(s), {input_6} cup(s) of hot coffee and {input_5} bottle(s) of water coming up""")
                Total_bill = (f"Total bill: ${(input_4*5)+(input_6*7)+(input_5*1)}")
            elif input_3 == 3:
                input_26 = int(input('how many more cup(s) of hot coffee do you want?'))
                order = (f"""{input_4} krabbypaddy(s), and {input_6+input_26} cup(s) of hot coffee coming up""")
                Total_bill = (f"Total bill: ${(input_4*5)+((input_6+input_26)*7)}")
            elif input_3 == 4:
                input_7 = int(input('how many marcoroni and cheese do you want?'))
                order = (f"""{input_4} krabbypaddy(s), {input_6} cup(s) of hot coffee and {input_7} marcoroni and cheese coming up""")
                Total_bill = (f"Total bill: ${(input_4*5)+(input_6*7)+(input_7*10)}")
            elif input_3 == 5:
                order = (f"""{input_4} krabbypaddy(s) and {input_6} cup(s) of hot coffee coming up""")
                Total_bill = (f"Total bill: ${(input_4*5)+(input_6*7)}")
            else:
                print('invalid input, please pick a number from the list.')
            print(order)
            print(Total_bill)
        elif input_3 == 4:
            input_7 = int(input('how many marcoroni and cheese do you want?'))
            input_3 = int(input('anything else?'))
            if input_3 == 1:
                input_26 = int(input('how many more krabbypaddy(s) do you want?'))
                order = (f"""{input_4+input_26} krabbypaddy(s) and {input_7} marcoroni and cheese coming up""")
                Total_bill = (f"Total bill: ${((input_4+input_26)*5)+(input_7*10)}")
            elif input_3 == 2:
                input_5 = int(input('how many bottle(s) of water do you want?'))
                order = (f"""{input_4} krabbypaddy(s), {input_7} marcoroni and cheese and {input_5} bottle(s) of water coming up""")
                Total_bill = (f"Total bill: ${(input_4*5)+(input_7*10)+(input_5*1)}")
            elif input_3 == 3:
                input_6 = int(input('how many cup(s) of hot coffee do you want?'))
                order = (f"""{input_4} krabbypaddy(s), {input_7} marcoroni and cheese and {input_6} cup(s) of hot coffee coming up""")
                Total_bill = (f"Total bill: ${(input_4*5)+(input_7*10)+(input_6*7)}")
            elif input_3 == 4:
                input_27 = int(input('how many more marcoroni and cheese do you want?'))
                order = (f"""{input_4} krabbypaddy(s) and {input_7+input_27} marcoroni and cheese coming up""")
                Total_bill = (f"Total bill: ${(input_4*5)+((input_7+input_27)*10)}")
            elif input_3 == 5:
                order = (f"""{input_4} krabbypaddy(s) and {input_7} marcoroni and cheese coming up""")
                Total_bill = (f"Total bill: ${(input_4*5)+(input_7*10)}")
            else:
                print('invalid input, please pick a number from the list.')
            print(order)
            print(Total_bill)
        elif input_3 == 5:
            print('thank you')
            print(order)
            print(Total_bill)
        else:
            print('invalid input, please pick a number from the list.')
    elif input_2 == 2:
        input_5 = int(input('how many bottle(s) of water do you want?'))
        order = (f"""{input_5} bottle(s) of water coming up""")
        Total_bill = (f"Total bill: ${input_5}")
        for i in show_menu:
            print(i)
        print('5. nothing else')
        input_3 = int(input('anything else?'))
        if input_3 == 1:
            input_4 = int(input('how many krabbypaddy(s) do you want?'))
            input_3 = int(input('anything else?'))
            if input_3 == 1:
                input_16 = int(input('how many more krabbypaddy(s) do you want?'))
                order = (f"""{input_5} bottle(s) of water, and {input_16+input_4} krabbypaddy(s) coming up""")
                Total_bill = (f"Total bill: ${(input_5*1)+((input_16+input_4)*5)}")
            elif input_3 == 2:
                input_17 = int(input('how many more bottle(s) of water do you want?'))
                order = (f"""{(input_17+input_5)} bottle(s) of water, and {input_4} krabbypaddy(s) coming up""")
                Total_bill = (f"Total bill: ${((input_17+input_5)*1)+(input_4*5)}")
            elif input_3 == 3:
                input_6 = int(input('how many cup(s) of coffee do you want?'))
                order = (f"""{input_5} bottle(s) of water, {input_4} krabbypaddy(s) and {input_6} cup(s) of coffee coming up""")
                Total_bill = (f"Total bill: ${(input_5*1)+(input_4*5)+(input_6*7)}")
            elif input_3 == 4:
                input_7 = int(input('how many marcoroni and cheese do you want?'))
                order = (f"""{input_5} bottle(s) of water, {input_4} krabbypaddy(s) and {input_7} marcoroni and cheese coming up""")
                Total_bill = (f"Total bill: ${(input_5*1)+(input_4*5)+(input_7*10)}")
            elif input_3 == 5:
                order = (f"""{input_5} bottle(s) of water and {input_4} krabbypaddy(s) coming up""")
                Total_bill = (f"Total bill: ${(input_5*1)+(input_4*5)}")
            else:
                print('invalid input, please pick a number from the list.')
            print(order)
            print(Total_bill)
        elif input_3 == 2:
            print('you have already ordered for bottle(s) of water, please take a new order')
            print(order)
            print(Total_bill)
        elif input_3 == 3:
            input_6 = int(input('how many cup(s) of hot coffee do you want?'))
            input_3 = int(input('anything else?'))
            if input_3 == 1:
                input_4 = int(input('how many krabbypaddy(s) do you want?'))
                order = (f"""{input_5} bottle(s) of water, {input_6} cup(s) of hot coffee and {input_4} krabbypaddy(s) coming up""")
                Total_bill = (f"Total bill: ${(input_5*1)+(input_6*7)+(input_4*5)}")
            elif input_3 == 2:
                input_18 = int(input('how many more bottle(s) of water do you want?'))
                order = (f"""{((input_5+input_18))} bottle(s) of water and {input_6} cup(s) of hot coffee coming up""" )
                Total_bill = (f"Total bill: ${((input_5+input_18)*1)+(input_6*7)}")
            elif input_3 == 3:
                input_19 = int(input('how many more cup(s) of hot coffee do you want?'))
                order = (f"""{input_5} bottle(s) of water, and {(input_6+input_19)} cup(s) of hot coffee coming up""")
                Total_bill = (f"Total bill: ${(input_5*1)+((input_6+input_19)*7)}")
            elif input_3 == 4:
                input_7 = int(input('how many marcoroni and cheese do you want?'))
                order = (f"""{input_5} bottle(s) of water, {input_6} cup(s) of hot coffee and {input_7} marcoroni and cheese coming up""")
                Total_bill = (f"Total bill: ${(input_5*1)+(input_6*7)+(input_7*10)}")
            elif input_3 == 5:
                order = (f"""{input_5} bottle(s) of water and {input_6} cup(s) of hot coffee coming up""")
                Total_bill = (f"Total bill: ${(input_5*1)+(input_6)}")
            else:
                print('invalid input, please pick a number from the list.')
            print(order)
            print(Total_bill)
        elif input_3 == 4:
            input_7 = int(input('how many marcoroni and cheese do you want?'))
            input_3 = int(input('anything else?'))
            if input_3 == 1:
                input_4 = int(input('how many krabbypaddy(s) do you want?'))
                order = (f"""{input_5} bottle(s) of water, {input_7} marcoroni and cheese and {input_4} krabbypaddy(s) coming up""")
                Total_bill = (f"Total bill: ${(input_5*1)+(input_7*10)+(input_4*5)}")
            elif input_3 == 2:
                input_20 = int(input('how many more bottle(s) of water do you want?'))
                order = (f"""{input_20+input_5} bottle(s) of water, and {input_7} marcoroni and cheese coming up""")
                Total_bill = (f"Total bill: ${((input_20+input_5)*1)+(input_7*10)}")
            elif input_3 == 3:
                input_6 = int(input('how many cup(s) of hot coffee do you want?'))
                order = (f"""{input_5} bottle(s) of water, {input_7} marcoroni and cheese and {input_6} cup(s) of hot coffee coming up""")
                Total_bill = (f"Total bill: ${(input_5*1)+(input_7*10)+(input_6*7)}")
            elif input_3 == 4:
                input_21 = int(input('how many more marcoroni and cheese do you want?'))
                order = (f"""{input_5} bottle(s) of water and {input_7+input_21} marcoroni and cheese coming up""")
                Total_bill = (f"Total bill: ${(input_5*1)+((input_7+input_21)*10)}")
            elif input_3 == 5:
                order = (f"""{input_5} bottle(s) of water and {input_7} marcoroni and cheese coming up""")
                Total_bill = (f"Total bill: ${(input_5*1)+(input_7*10)}")
            else:
                print('invalid input, please pick a number from the list.')
            print(order)
            print(Total_bill)
        elif input_3 == 5:
            print('thank you')
            print(order)
            print(Total_bill)
        else:
            print('invalid input, please pick a number from the list.')
    elif input_2 == 3:
        input_6 = int(input('how many cup(s) of hot coffee do you want?'))
        order = (f"""{input_6} cup(s) of hot coffee coming up""")
        Total_bill = (f"Total bill: ${(input_6*7)}")
        for i in show_menu:
            print(i)
        print('5. nothing else')
        input_3 = int(input('anything else'))
        if input_3 == 1:
            input_4 = int(input('how many krabbypaddy(s) do you want?'))
            input_3 = int(input('anything else?'))
            if input_3 == 1:
                input_14 = int(input('how many more krabbypaddy(s) do you want?'))
                order = (f"""{input_6} hot cup(s) of coffee and {input_4+input_14} krabbypaddy(s) coming up""")
                Total_bill = (f"Total bill: ${(input_6*7)+((input_4+input_14)*5)}")
            elif input_3 == 2:
                input_5 = int(input('how many bottle(s) of water do you want?'))
                order = (f"""{input_6} hot cup(s) of coffee, {input_4} krabbypaddy(s) and {input_5} bottle(s) of water coming up""")
                Total_bill = (f"Total bill: ${(input_6*7)+(input_4*5)+(input_5*1)}")
            elif input_3 == 3:
                input_15 = int(input('how many more cup(s) of coffee do you want?'))
                order = (f"""{input_6+input_15} cup(s) of hot coffee and {input_4} krabbypaddy(s) coming up""")
                Total_bill = (f"Total bill: ${((input_6+input_15)*7)+(input_4*5)}")
            elif input_3 == 4:
                input_7 = int(input('how many marcoroni and cheese do you want?'))
                order = (f"""{input_6} cup(s) of hot coffee, {input_4} krabbypaddy(s) and {input_7} marcoroni and cheese coming up""")
                Total_bill = (f"Total bill: ${(input_6*7)+(input_4*5)+(input_7*10)}")
            elif input_3 == 5:
                order = (f"""{input_6} cup(s) of hot coffee and {input_4} krabbypaddy(s) coming up""")
                Total_bill = (f"Total bill: ${(input_6*7)+(input_4*5)}")
            else:
                print("invalid input, please pick a number from the list.")
            print(order)
            print(Total_bill)
        elif input_3 == 2:
            input_5 = int(input('how many bottle(s) of water do you want?')) 
            input_3 = int(input('anything else?'))
            if input_3 == 1:
                input_4 = int(input('how many krabbypaddy(s) do you want?'))
                order = (f"""{input_6} hot cup(s) of coffee, {input_5} bottle(s) of water and {input_4} krabbypaddy(s) coming up""")
                Total_bill = (f"Total bill: ${(input_6*7)+(input_5*1)+(input_4*5)}")
            elif input_3 == 2:
                input_15 = int(input('how many more bottle(s) of water do you want?'))
                order = (f"""{input_6} hot cup(s) of coffee and {input_5+input_15} bottle(s) of water coming up""")
                Total_bill = (f"Total bill: ${(input_6*7)+((input_5+input_15)*1)}")
            elif input_3 == 3:
                input_16 = int(input('how many more cup(s) of hot coffee do you want?'))
                order = (f"""{input_16+input_6} cup(s) of hot coffee and {input_5} bottle(s) of water coming up""")
                Total_bill = (f"Total bill: ${((input_16+input_6)*7)+(input_5*1)}")
            elif input_3 == 4:
                input_7 = int(input('how many marcoroni and cheese do you want?'))
                order =(f"""{input_6} cup(s) of hot coffee, {input_5} bottle(s) of water and {input_7} marcoroni and cheese coming up""")
                Total_bill =(f"Total bill: ${(input_6*7)+(input_5*1)+(input_7*10)}")
            elif input_3 == 5:
                order = (f"""{input_6} cup(s) of hot coffee, and {input_5} bottle(s) of water coming up""")
                Total_bill =(f"Total bill: ${(input_6*7)+(input_5*1)}")
            else:
                print('invalid input, please pick a number from the list?')
            print(order)
            print(Total_bill)
        elif input_3 == 3:
            print('you have already ordered for cup(s) of hot coffee, please take a new order')
            print(order)
            print(Total_bill)
        elif input_3 == 4:
            input_7 = int(input('how many marcoroni and cheese do you want?'))
            input_3 = int(input('anything else?'))
            if input_3 == 1:
                input_4 = int(input('how many krabbypaddy(s) do you want?'))
                order = (f"""{input_6} cup(s) of hot coffee, {input_7} marcoroni and cheese and {input_4} krabbypaddy(s) coming up""")
                Total_bill = (f"Total bill: ${(input_6*7)+(input_7*10)+(input_4*5)}")
            elif input_3 == 2:
                input_5 = int(input('how many bottle(s) of water do you want?'))
                order = (f"""{input_6} cup(s) of hot coffee, {input_7} marcoroni and cheese and {input_5} bottle(s) of water coming up""")
                Total_bill = (f"Total bill: ${(input_6*7)+(input_7*10)+(input_5*1)}")
            elif input_3 == 3:
                input_21 = int(input('how many more cup(s) of hot coffee do you want?'))
                order = (f"""{input_6+input_21} cup(s) of hot coffee and {input_7} marcoroni and cheese coming up""")
                Total_bill = (f"Total bill: ${((input_6+input_21)*7)+(input_7*10)}")
            elif input_3 == 4:
                input_22 = int(input('how many more marcoroni and cheese do you want?'))
                order = (f"""{input_6} cup(s) of hot coffee and {input_7+input_22} marcoroni and cheese coming up""")
                Total_bill = (f"Total bill: ${(input_6*7)+((input_7+input_22)*10)}")
            elif input_3 == 5:
                order = (f"""{input_6} cup(s) of hot coffee and {input_7} marcoroni and cheese coming up""")
                Total_bill = (f"Total bill: ${(input_6*7)+(input_7*10)}")
            else:
                print('invalid input, please pick a value from the list.')
            print(order)
            print(Total_bill)
        elif input_3 == 5:
            print('thank you')
            print(order)
            print(Total_bill)
        else:
            print('invalid input, please pick a number from the list')
    elif input_2 == 4:
        input_7 = int(input('how many marcoroni and cheese do you want?'))
        order = (f"""{input_7} marcoroni and cheese coming up""")
        Total_bill = (f"Total bill: ${(input_7*10)}")
        for i in show_menu:
            print(i)
        print('5. nothing else')
        input_3 = int(input('anything else?'))
        if input_3 == 1:
            input_4 = int(input('how many krabbypaddy(s) do you want?'))
            input_3 = int(input('anything else?'))
            if input_3 == 1:
                input_8 = int(input('how many more krabbypaddy(s) would you like to have?'))
                order = (f"""{input_7} marcoroni and cheese, and , {input_4+input_8} krabbypaddy(s) coming up""")
                Total_bill = (f"Total bill: ${(input_7*10)+((input_4+input_8)*5)}")
            elif input_3 == 2:
                input_5 = int(input('how many bottles of water do you want?'))
                order = (f"""{input_7} marcoroni and cheese, {input_4} krabbypaddy(s) and {input_5} bottle(s) of water coming up""")
                Total_bill = (f"Total bill: ${(input_7*10)+(input_4*5)+(input_5*1)}")
            elif input_3 == 3:
                input_6 = int(input('how many cup(s) of hot coffee do you want?'))
                order = (f"""{input_7} marcoroni and cheese, {input_4} krabbypaddy(s) and {input_6} cup(s) of hot coffee coming up""")
                Total_bill = (f"Total bill: ${(input_7*10)+(input_4*5)+(input_6*7)}")
            elif input_3 == 4:
                input_9 = int(input('how many more marcoroni and cheese do you want?'))
                order = (f"""{input_7+input_9} marcoroni and cheese, {input_4} krabbypaddy(s) coming up""")
                Total_bill = (f"Total bill: ${((input_7+input_9)*10)+(input_4*5)}")
            elif input_3 == 5:
                order = (f"""{input_7} marcoroni and cheese and {input_4} krabbypaddy(s) coming up""")
                Total_bill = (f"Total bill: ${(input_7*10)+(input_4*5)}")
            else:
                print('invalid input, please pick a number from the list.')
            print(order)
            print(Total_bill)
        elif input_3 == 2:
            input_5 = int(input('how many bottle(s) of water do you want?'))
            input_3 = int(input('anything else?'))
            if input_3 == 1:
                input_4 = int(input('how many krabbypaddy(s) do you want?'))
                order = (f"""{input_7} marcoroni and cheese, {input_5} bottle(s) of water and {input_4} krabbypaddy(s) coming up""")
                Total_bill = (f"Total bill: ${(input_7*10)+(input_5*1)+(input_4*5)}")
            elif input_3 == 2:
                input_10 = int(input('how many more bottle(s) of water do you want?'))
                order = (f"""{input_7} marcoroni and cheese and {input_5+input_10} bottle(s) of water coming up""")
                Total_bill = (f"Total bill: ${((input_7*10)+(input_5+input_10)*1)}")
            elif input_3 == 3:
                input_6 = int(input('how many cup(s) of hot coffee do you want?'))
                order = (f"""{input_7} marcoroni and cheese, {input_5} bottle(s) of water and {input_6} cup(s) of hot coffee coming up""")
                Total_bill = (f"Total bill: ${(input_7*10)+(input_5*1)+(input_6*7)}")
            elif input_3 == 4:
                input_11 = int(input('how many more marcoroni and cheese do you want?'))
                order = (f"""{input_7+input_11} marcoroni and cheese and {input_5} bottle(s) of water coming up""")
                Total_bill = (f"Total bill: ${((input_7+input_11)*10)+(input_5*1)}")
            elif input_3 == 5:
                order = (f"""{input_7} marcoroni and cheese and {input_5} bottle(s) of water coming up""")
                Total_bill = (f"Total bill: ${(input_7*10)+(input_5*1)}")
            else:
                print('invalid input, please pick a number from the list?')
            print(order)
            print(Total_bill)
        elif input_3 == 3:
            input_6 = int(input('how many cup(s) of hot coffee do you want?'))
            input_3 = int(input('anything else?'))
            if input_3 == 1:
                input_4 = int(input('how many krabbypaddy(s) do you want?'))
                order = (f"""{input_7} marcoroni and cheese, {input_6} cup(s) of hot coffee and {input_4} krabbypaddy(s) coming up""")
                Total_bill = (f"Total bill: ${(input_7*10)+(input_6*7)+(input_4*5)}")
            elif input_3 == 2:
                input_5 = int(input('how many bottle(s) of water do you want?'))
                order = (f"""{input_7} marcoroni and cheese, {input_6} cup(s) of hot coffee and {input_5} bottle(s) of water coming up""")
                Total_bill = (f"Total bill: ${(input_7*10)+(input_6*7)+(input_5*1)}")
            elif input_3 == 3:
                input_12 = int(input('how many more cup(s) of coffee do you want?'))
                order = (f"""{input_7} marcoroni and cheese and {input_6+input_12} cup(s) of coffee coming up""")
                Total_bill = (f"Total bill: ${((input_7*10)+(input_6+input_12)*7)}")
            elif input_3 == 4:
                input_13 = int(input('how many more marcoroni and cheese do you want?'))
                order = (f"""{input_7+input_13} marcoroni and cheese and {input_6} cup(s) of coffee coming up""")
                Total_bill = (f"Total bill: ${((input_7+input_13)*10)+(input_6*7)}")
            elif input_3 == 5:
                order = (f"""{input_7} marcoroni and cheese and {input_6} cup(s) of coffee coming up""")
                Total_bill = (f"Total bill: ${(input_7*10)+(input_6*7)}")
            else:
                print('invalid input, please pick a number from the list.')
            print(order)
            print(Total_bill)
        elif input_3 == 4:
            print(order)
            print(Total_bill)
            print('you have already ordered marcoroni and cheese, please take a new order.')
        elif input_3 == 5:
            print('thank you')
            print(order)
            print(Total_bill)
        else:
            print('invalid input, please pick a number from the list.')
# Out:
# welcome to krusty crab
# may i take your order Sir/Maam?
# yes
# 1. krabbypaddy $5
# 2. water $1
# 3. hott coffee $7
# 4. marcoroni and cheese $10
# your order Sir/Maam?1
# how many krabbypaddy(s) do you want?5
# 1. krabbypaddy $5
# 2. water $1
# 3. hott coffee $7
# 4. marcoroni and cheese $10
# 5. nothing else
# anything else?2
# how many bottle(s) of water?5
# anything else?1
# how many more krabbypaddy(s) do you want?6
# anything else?1
# how many more krabbypaddy(s) do you want?5
# 16 krabbypaddy(s) and 5 bottle(s) of water coming up
# Total bill: $85
# 11 krabbypaddy(s) and 5 bottle(s) of water coming up
# Total bill: $60
